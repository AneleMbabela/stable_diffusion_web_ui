# %%
# !pip install diffuzers -qqqq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 836.1/836.1 KB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.9/524.9 KB 40.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 KB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.4/235.4 KB 23.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 74.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 KB 37.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 65.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.5/191.5 KB 22.7 MB/s eta 0:00:00
# ...

# %%
# !diffuzers run --port 10000  & npx localtunnel --port 10000
# Out:
# npx: installed 22 in 5.412s
# your url is: https://chatty-news-post-146-148-35-88.loca.lt
#
#   You can now view your Streamlit app in your browser.
#
#   URL: http://127.0.0.1:10000
#
# > INFO    Args: Namespace(device='cuda', output=None)
# > INFO    {}
# > INFO    Args: Namespace(device='cuda', output=None)
# > INFO    {'output_path': None, 'FormSubmitter:x2img_model_form-Load model': False, 'device': 'cuda'}
#
# Downloading:   0%|          | 0.00/539 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 539/539 [00:00<00:00, 511kB/s]
#
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Downloading:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 342/342 [00:00<00:00, 265kB/s]
#
# Fetching 16 files:   6%|▋         | 1/16 [00:00<00:03,  3.76it/s]
#
# Downloading:   0%|          | 0.00/308 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 308/308 [00:00<00:00, 315kB/s]
#
# Fetching 16 files:  19%|█▉        | 3/16 [00:00<00:02,  6.06it/s]
#
# ...
